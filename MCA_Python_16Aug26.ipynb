# %% [markdown]
# <a href="https://colab.research.google.com/github/soumitra-001/MCA/blob/main/MCA_Python_16Aug26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3+4
# Out:
# 7

# %%
s1 = float(3)
type(s1)
# Out:
# float

# %%
s1 = 3
type(s1)
# Out:
# int

# %%
s1 = str(3)
type(s1)
# Out:
# str

# %%
a = 'h'
a = int(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1178/2063153177.py in <cell line: 0>()
#       1 a = 'h'
# ----> 2 a = int(a)
#       3 type(a)
#
# ValueError: invalid literal for int() with base 10: 'h'

# %%
z = 1 +2j
type(z)
# Out:
# complex

# %%
z1 = 1j
z2 = 2 + 3j
print(z1+z2)
# Out:
# (2+4j)

# %%
c = 1
type(c)
# Out:
# int

# %%
c = complex(c)
type(c)
# Out:
# complex

# %%
print(c)
# Out:
# (1+0j)

# %%
c1 = 1j
c1 = int(c1) # complex is not typecastable
type(c1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1178/945740187.py in <cell line: 0>()
#       1 c1 = 1j
# ----> 2 c1 = int(c1) # complex is not typecastable
#       3 type(c1)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
s = "abcdefgh"
print(s)
# Out:
# abcdefgh

# %%
print(s[0])
print(s[1])
# Out:
# a
# b

# %%
print(s[0],s[1],s[2],s[3],s[4],s[5],s[6]) # side by side printing
print(s[0]+s[1]+s[2]+s[3]+s[4]+s[5]+s[6]) # sting concatination
# Out:
# a b c d e f g
# abcdefg

# %%
print(s[0:5]) # 0 to 4
print(s[0 : ])
print(s[0 : len(s) ])
# Out:
# abcde
# abcdefgh
# abcdefgh

# %%
print(s[-1])
print(s[-1],s[-2],s[-3],s[-4],s[-6],s[-7],s[-8])
# Out:
# h
# h g f e c b a

# %%
print(s[-5:-1])
print(s[-8:])
print(s[-8: 8])
# Out:
# defg
# abcdefgh
# abcdefgh

# %%
a = 'soumitra'
len(a)
# Out:
# 8

# %%
a = '        soumitra           '
len(a)
# Out:
# 27

# %%
b = a.strip()
len(b)
# Out:
# 8
# 8

# %%
a = 'hi'
b = a.replace('h','x')
print (a,b)
# Out:
# hi xi

# %%
s2 = 'hello,world'
s3 = s2.split(',')
print(s2)
print(s3[0],s3[1])
# Out:
# hello,world
# hello world

# %%
age = 22
s = f"soumitra age is {age}" #{} are used as placeholder for variable
print(s)
# Out:
# soumitra age is 22

# %%
price = 50
s5 = f"rice cost is {price}"
s6 = f"rice cost is {price:.2f}" #{} are used as placeholder for variable
print(s5)
print(s6)
s7 = f"2 kg rice cost is {price* 2:.2f}"
print(s7)
# Out:
# rice cost is 50
# rice cost is 50.00
# 2 kg rice cost is 100.00

# %%
score = 94.56223
s10 = f"score :{score:>8.2f} | status : {'PASS':^10}"
# after decimal 2 digit , 8 is minimum 8 char,^ is center align
print(s10)
# Out:
# score :12345678094.56 | status :    PASS

# %%
name = 'AI'
s11 = f"{name:*^10}"
print(s11)
# outcome is 10 character length
# * fill character with *
# ^ is for center alignment
# Out:
# ****AI****

# %%
name = 'AI'
s11 = f"{name:+>8}"
print(s11)
# outcome is 8 character length
# + fill character with *
# > is for right alignment
# Out:
# ++++++AI

# %%
name = 'AI'
s11 = f"{name:-<11}"
print(s11)
# outcome is 11 character length
# - fill character with *
# < is for left alignment
# Out:
# AI---------

# %%
x = -45.68
s13 = f"result:{x:=10.2f}"
print(s13)
# Out:
# result:-    45.68

# %%
x = -45.68
s13 = f"result:{x:*=10.2f}" # = is for sign-aware padding
print(s13)
type(s13)
# Out:
# result:-****45.68
# str
